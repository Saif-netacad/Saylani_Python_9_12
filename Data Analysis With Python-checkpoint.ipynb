# %% [markdown]
# # Importing Data SET

# %%
import os 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SAIF ULLAH'

# %%
df = pd.read_excel('C://Users//SAIF ULLAH//data.xlsx') # loading excel data

# %%
df.head() #it will show defaults first five rows
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  MX-2014-143658 2014-10-02 2014-10-06  Standard Class    SC-20575
# 1       2  MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 2       3  MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 3       4  MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 4       5  MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
#
#     Customer Name   Segment                    City, State   Country  ...  \
# 0    Sonia Cooley  Consumer  Mexico City, Distrito Federal    Mexico  ...
# 1  Kelly Williams  Consumer       Dos Quebradas, Risaralda  Colombia  ...
# 2  Kelly Williams  Consumer       Dos Quebradas, Risaralda  Colombia  ...
# 3  Kelly Williams  Consumer       Dos Quebradas, Risaralda  Colombia  ...
# 4  Kelly Williams  Consumer       Dos Quebradas, Risaralda  Colombia  ...
#
#         Product ID         Category Sub-Category  \
# ...

# %%
#df.head() by adding number of row  in bracket it will shows those rows
# lets suppose i want to show first 10 rowa
df.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  MX-2014-143658 2014-10-02 2014-10-06  Standard Class    SC-20575
# 1       2  MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 2       3  MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 3       4  MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 4       5  MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 5       6  MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 6       7  MX-2013-134096 2013-09-27 2013-10-01  Standard Class    DP-13000
# 7       8  MX-2013-134096 2013-09-27 2013-10-01  Standard Class    DP-13000
# 8       9  MX-2013-134096 2013-09-27 2013-10-01  Standard Class    DP-13000
# 9      10  MX-2013-134096 2013-09-27 2013-10-01  Standard Class    DP-13000
#
#     Customer Name   Segment                    City, State   Country  ...  \
# ...

# %% [markdown]
# ### Loading data without header

# %%
# loading data without header 
# printing first two rows
without_header =pd.read_excel('C://Users//SAIF ULLAH//data.xlsx', header=None)
without_header.head(2)
# Out:
#        0               1                    2                    3   \
# 0  Row ID        Order ID           Order Date            Ship Date
# 1       1  MX-2014-143658  2014-10-02 00:00:00  2014-10-06 00:00:00
#
#                4            5              6         7   \
# 0       Ship Mode  Customer ID  Customer Name   Segment
# 1  Standard Class     SC-20575   Sonia Cooley  Consumer
#
#                               8        9   ...               13  \
# 0                    City, State  Country  ...       Product ID
# 1  Mexico City, Distrito Federal   Mexico  ...  OFF-LA-10002782
#
#                 14            15                                  16     17  \
# 0         Category  Sub-Category                        Product Name  Sales
# 1  Office Supplies        Labels  Hon File Folder Labels, Adjustable  13.08
#
#          18        19      20             21              22
# 0  Quantity  Discount  Profit  Shipping Cost  Order Priority
# ...

# %% [markdown]
# ## Print last few entries

# %%
# df.tail() show default last 5 entry 
# showing just last two entry
df.tail(2)
# Out:
#        Row ID      Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 51288   51289  HU-2012-7730 2012-09-05 2012-09-07     First Class     NF-8385
# 51289   51290  IZ-2011-5750 2011-08-25 2011-08-29  Standard Class    SZ-10035
#
#           Customer Name      Segment         City, State  Country  ...  \
# 51288  Natalie Fritzler     Consumer  Budapest, Budapest  Hungary  ...
# 51289        Sam Zeldin  Home Office    Baghdad, Baghdad     Iraq  ...
#
#              Product ID         Category Sub-Category  \
# 51288  OFF-ENE-10004132  Office Supplies        Paper
# 51289  OFF-ACC-10002343  Office Supplies      Binders
#
#                                     Product Name   Sales Quantity Discount  \
# 51288  Enermax Computer Printout Paper, 8.5 x 11  130.44        4      0.0
# 51289                 Acco 3-Hole Punch, Durable   31.62        1      0.0
#
#        Profit  Shipping Cost  Order Priority
# 51288   33.84          18.97            High
# ...

# %%
# this will shows all colums headers/column name
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City, State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# ## Replace "?" with NaN

# %%
# this will replace all "?" with NaN to make data readable
df.replace( "?", np.NaN)
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  MX-2014-143658 2014-10-02 2014-10-06  Standard Class
# 1           2  MX-2012-155047 2012-10-15 2012-10-20  Standard Class
# 2           3  MX-2012-155047 2012-10-15 2012-10-20  Standard Class
# 3           4  MX-2012-155047 2012-10-15 2012-10-20  Standard Class
# 4           5  MX-2012-155047 2012-10-15 2012-10-20  Standard Class
# ...       ...             ...        ...        ...             ...
# 51285   51286    HU-2012-7730 2012-09-05 2012-09-07     First Class
# 51286   51287    HU-2012-7730 2012-09-05 2012-09-07     First Class
# 51287   51288    HU-2012-7730 2012-09-05 2012-09-07     First Class
# 51288   51289    HU-2012-7730 2012-09-05 2012-09-07     First Class
# 51289   51290    IZ-2011-5750 2011-08-25 2011-08-29  Standard Class
#
#       Customer ID     Customer Name      Segment  \
# 0        SC-20575      Sonia Cooley     Consumer
# ...

# %% [markdown]
# ## Retrieve the data types of the data frame columns

# %%
# this will all columns data tpyes like int, object, float etc
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City, State               object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %% [markdown]
# ## Statistical description
# - df.describe()     ---- it will only shows numerical data
# - df.describe(include ="all")    ---will describe the whole data

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155780864
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2011-01-03 00:00:00   1040.000000      0.444000
# 25%              2012-06-23 00:00:00  23223.000000     30.758625
# 50%              2013-07-12 00:00:00  56430.500000     85.053000
# 75%              2014-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
df.describe(include="all")
# Out:
#              Row ID        Order ID                     Order Date  \
# count   51290.00000           51290                          51290
# unique          NaN           25035                            NaN
# top             NaN  CA-2014-100111                            NaN
# freq            NaN              14                            NaN
# mean    25645.50000             NaN  2013-05-11 21:26:49.155780864
# min         1.00000             NaN            2011-01-01 00:00:00
# 25%     12823.25000             NaN            2012-06-19 00:00:00
# 50%     25645.50000             NaN            2013-07-08 00:00:00
# 75%     38467.75000             NaN            2014-05-22 00:00:00
# max     51290.00000             NaN            2014-12-31 00:00:00
# std     14806.29199             NaN                            NaN
#
#                             Ship Date       Ship Mode Customer ID  \
# count                           51290           51290       51290
# ...

# %% [markdown]
# ## Data set Summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City, State     51290 non-null  object
#  9   Country         51290 non-null  object
#  10  Postal Code     9994 non-null   float64
#  11  Market          51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Product ID      51290 non-null  object
#  14  Category        51290 non-null  object
#  15  Sub-Category    51290 non-null  object
# ...

# %% [markdown]
# # Data Wrangling

# %% [markdown]
#  ### Data Normalization

# %%
#Normalize the data in a column such that the values are restricted between 0 and 1.
df["Quantity"] =df["Quantity"]/df["Quantity"].max()

# %%
df["Quantity"]
# Out:
# 0        0.214286
# 1        0.571429
# 2        0.142857
# 3        0.285714
# 4        0.142857
#            ...
# 51285    0.071429
# 51286    0.142857
# 51287    0.285714
# 51288    0.285714
# 51289    0.071429
# Name: Quantity, Length: 51290, dtype: float64

# %% [markdown]
# ## Change column name

# %%
# it will rename the column and will print it
df.rename(columns={"Quantity":"normalized_quantity"}, inplace =True)
df["normalized_quantity"]
# Out:
# 0        0.214286
# 1        0.571429
# 2        0.142857
# 3        0.285714
# 4        0.142857
#            ...
# 51285    0.071429
# 51286    0.142857
# 51287    0.285714
# 51288    0.285714
# 51289    0.071429
# Name: normalized_quantity, Length: 51290, dtype: float64

# %% [markdown]
# ## Indicator Variables
# - Create indicator variables for categorical data

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City, State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'normalized_quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
Dummy_category = pd.get_dummies(df["Category"])
Dummy_category
# Out:
#        Furniture  Office Supplies  Technology
# 0          False             True       False
# 1           True            False       False
# 2           True            False       False
# 3          False             True       False
# 4          False             True       False
# ...          ...              ...         ...
# 51285      False             True       False
# 51286      False            False        True
# 51287      False             True       False
# 51288      False             True       False
# 51289      False             True       False
#
# [51290 rows x 3 columns]

# %%
# it will create extra column in data of category 
df =pd.concat([df, Dummy_category], axis=1)
df
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  MX-2014-143658 2014-10-02 2014-10-06  Standard Class
# 1           2  MX-2012-155047 2012-10-15 2012-10-20  Standard Class
# 2           3  MX-2012-155047 2012-10-15 2012-10-20  Standard Class
# 3           4  MX-2012-155047 2012-10-15 2012-10-20  Standard Class
# 4           5  MX-2012-155047 2012-10-15 2012-10-20  Standard Class
# ...       ...             ...        ...        ...             ...
# 51285   51286    HU-2012-7730 2012-09-05 2012-09-07     First Class
# 51286   51287    HU-2012-7730 2012-09-05 2012-09-07     First Class
# 51287   51288    HU-2012-7730 2012-09-05 2012-09-07     First Class
# 51288   51289    HU-2012-7730 2012-09-05 2012-09-07     First Class
# 51289   51290    IZ-2011-5750 2011-08-25 2011-08-29  Standard Class
#
#       Customer ID     Customer Name      Segment  \
# 0        SC-20575      Sonia Cooley     Consumer
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Complete dataframe correlation
# Correlation matrix created using all the attributes of the dataset

# %%
# df.corr() it will return error it is because data has some non-numeric data so first we get numeric data first
df_numeric = df.select_dtypes(include=[np.number])

# %%
df_numeric.corr()
# Out:
#                        Row ID  Postal Code     Sales  normalized_quantity  \
# Row ID               1.000000     0.009671 -0.043889            -0.173483
# Postal Code          0.009671     1.000000 -0.023854             0.012761
# Sales               -0.043889    -0.023854  1.000000             0.313577
# normalized_quantity -0.173483     0.012761  0.313577             1.000000
# Discount             0.087594     0.058443 -0.086722            -0.019875
# Profit              -0.019037    -0.029961  0.484918             0.104365
# Shipping Cost       -0.031558    -0.020175  0.809589             0.251397
#
#                      Discount    Profit  Shipping Cost
# Row ID               0.087594 -0.019037      -0.031558
# Postal Code          0.058443 -0.029961      -0.020175
# Sales               -0.086722  0.484918       0.809589
# normalized_quantity -0.019875  0.104365       0.251397
# Discount             1.000000 -0.316490      -0.070157
# ...

# %% [markdown]
# ## Specific Attribute correlation
# Correlation matrix created using specific attributes of the dataset

# %%
#it will show correltaion between sales, profit and discount
df[["Profit", "Sales", "Discount"]].corr()
# Out:
#             Profit     Sales  Discount
# Profit    1.000000  0.484918 -0.316490
# Sales     0.484918  1.000000 -0.086722
# Discount -0.316490 -0.086722  1.000000

# %% [markdown]
# ## Scatter Plot
# creating scatter plot of correlated veriables

# %%
# Creating Scatter plot for Sales And Profit 
plt.scatter(df[["Sales"]],df[["Profit"]])

# %% [markdown]
# ## Regression Plot

# %% [markdown]
# ##

# %%
sns.regplot(x="Sales", y="Profit", data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# # Grouping

# %%
sales_data =pd.DataFrame(df)

# %%
#grouping by segment
grouped_sales =sales_data.groupby("Segment")

# %%
#sales vs Segment
tota_sales_by_product =grouped_sales["Sales"].sum()

# %%
# Total sales by each Segment
tota_sales_by_product
# Out:
# Segment
# Consumer       6.507949e+06
# Corporate      3.824698e+06
# Home Office    2.309855e+06
# Name: Sales, dtype: float64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City, State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'normalized_quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Furniture',
#        'Office Supplies', 'Technology'],
#       dtype='object')

# %%
grouped_profit =sales_data.groupby("Segment")
profit_by_segment =grouped_profit["Profit"].sum()
profit_by_segment
# Out:
# Segment
# Consumer       749239.78206
# Corporate      441208.32866
# Home Office    277009.18056
# Name: Profit, dtype: float64

# %% [markdown]
# # Plotting with Matplotlib using Pandas

# %%
df_grouped = df.groupby("Segment")["Sales"].mean().reset_index()

plt.figure(figsize=(10, 5))  # Adjust figure size as needed
plt.plot(df_grouped["Segment"], df_grouped["Sales"], marker="o", linestyle="-")
plt.xlabel("Segment")
plt.ylabel("Average Sales")
plt.title("Average Sales by Segment")
plt.grid(True)
plt.show()

# %%
plt.bar(df["Segment"], df["Sales"], color='blue')  # Adjust color as needed
plt.xlabel("Segment")
plt.ylabel("Sales")  # Adjust label if applicable
plt.title("Sales by Segment (Bar Chart)")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability with many categories
plt.grid(axis='y')  # Display grid lines on the y-axis
plt.tight_layout()  # Adjust spacing between elements for readability
plt.show()
